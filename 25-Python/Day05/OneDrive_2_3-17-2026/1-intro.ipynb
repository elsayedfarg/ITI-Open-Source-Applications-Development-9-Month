# %% [markdown]
# # Object-Oriented Programming (OOP) in Python
#
# OOP is a programming paradigm based on objects that encapsulate data and behavior.

# %% [markdown]
# ## 1. Understanding Dictionaries as a Basic Data Structure
# Dictionaries can be used to represent entities, but they lack structure and behavior.

# %% [markdown]
# > Employee Dictionary Example

# %%
emp1 = {
    "first_name": "Ahmed",
    "last_name": "Ali",
    "age": 25,
}

emp2 = {
    "fname": "Ali",
    "lname": "Mohamed",
    "age": 20
}
def print_employee_info(emp1: dict):
    print(f"Employee name is : {emp1['first_name']} {emp1['last_name']}, Age is: {emp1['age']} ")


#
def print_employee_info(emp1: dict):
    """Prints employee info."""
    try:
        print(f"Employee name is : {emp1['first_name']} {emp1['last_name']}, Age is: {emp1['age']} ")
    except KeyError:
        print("Invalid employee data format.")

# %%
print_employee_info(emp1)

# %%
print_employee_info(emp2)

# %% [markdown]
# ## 2. Classes in Python
# - **Class**: A class is a blueprint for creating objects. It defines the structure(attributes) and behaviors (attributes and methods) that the objects created from the class will have.
#
# - **Object**: An object is an instance of a class. When you create an object, you are creating an instance of a class.
#
# ---
#
# ### Benefits of Using Classes
# - ✅ **Encapsulation**: Groups related data and functions together.
# - ✅ **Code Reusability**: Classes allow for inheritance, enabling code reuse.
# - ✅ **Modularity**: Breaks down complex systems into smaller, more manageable components.
# - ✅ **Data Abstraction**: Hides the internal workings and exposes only necessary details.
#
# ---
# ### **● Class and Objects**
# ![Class Example](images/class1.webp "Class Example")
#
# ---
# ### **● Example On Class and Objects**
# ![Example On Class and Objects](images/class2.png "Class Example")    ![Example On Class and Objects](images/objects.png "Class Example")

# %% [markdown]
# > ### 2.1 Define a class

# %%
class Employee:
    pass            #A simple class without any attributes or methods.

# %% [markdown]
# > ### 2.2 Take an object from the class

# %%
x = 10.8
print(type(x))

# %%
emp = Employee()
print(emp)
# indicating the object's location in memory

# %%
print(type(emp))
print(type(10.5))

# %% [markdown]
# > - In Python, <span style="background:LemonChiffon">everything, including numbers, strings, functions, and even classes themselves, are objects</span>. **All these objects** belong to some **class**.
# > - so, can say <span style="background:LemonChiffon">Everything in Python is an instance of a class</span>

# %% [markdown]
# > **take an object from the class**

# %%
emp.name = 'Ahmed Ali'
emp.age= 20
emp.salary = 5000

# %%
print(emp)
emp.name

# %%
emp2 = Employee()
emp2.first_name = 'ahmed'
emp2.last_name = 'Ali'

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Object with default attribute values using Constructor
# we **customize object creation** by defining an `__init__` **constructor** method. This constructor allocates memory for the object and initializes it with **default attribute values**: `name`, `email`, and `salary`.

# %% [markdown]
# > name, email, and salary called instance variable

# %%
class Employee:
    """ Represents an Employee with default attributes: name, email, and salary."""

    def __init__(self):
        """ Initializes a new Employee object with default attribute values."""
        print("Object is being created")
        print(self)
        self.name = 'Ahmed Ali'
        self.email = 'ahmed@gmail.com'
        self.salary = 10000

emp3 = Employee()
emp4 = Employee()
print(emp3)

# emp4.email

# %% [markdown]
# - **`class` keyword**: Used to define a class.
# - **Class Definition**: <span style="background:LemonChiffon">The name of the class followed by parentheses `()`</span> (if inheriting from another class). This is the **Class Header**.
# - **Attributes**: Variables defined inside the class that represent properties of an object.
# - **Methods**: Functions defined inside the class that represent behaviors of an object.
# - **Constructor (`__init__`)**: A special method that initializes the object with specific values upon creation.
#   - <span style="background:LemonChiffon">The constructor method is automatically called when an object is created, initializing the object with specific attributes</span>.
# - **`self`**: A reference to the current instance of the class, allowing access to its attributes and methods.
# - **Docstring (`""" """`)**: A special comment placed immediately after the class definition that describes the class and its purpose.
#   - Enclosed in <span style="background:LemonChiffon">triple quotes</span>, allowing multi-line descriptions.
#   - Python recognizes a **docstring** if placed immediately after the class definition.

# %% [markdown]
# ---

# %% [markdown]
# ### 📝 **Notes**
#
# > - In Python, you can create **multiple objects** (also known as instances) from a single class.
# > - Each object will have its own independent copy of the attributes defined in the class.

# %%
emp1 = Employee()  # Creates an object and calls __init__()

# %%
emp2 = Employee()

# %% [markdown]
# > <span style="background:LemonChiffon">You can access or modify the attributes of an object using the **dot notation**</span>.

# %%
emp1.name

# %%
emp2.name = 'Mona Ali'  # Modify the 'name' attribute of emp2
emp2.name

# %% [markdown]
# ## 4. Customizing Constructor with Arguments

# %% [markdown]
# > <span style="background:LemonChiffon">`__init__` with parameters: The constructor now accepts name, email, and salary for object initialization.
#
# </span>

# %% [markdown]
# > - **The first argument is always `self`, which refers to the object calling the method.**
# > - The `self` parameter allows access to **instance-specific data**.

# %%
class Employee:
    """
    Represents an Employee with basic attributes: name, email, and salary.
    """
    def __init__(self, name, email, salary):
        """
        Initializes a new Employee object with specified values(Args).
        """
        self.name = name
        self.email = email
        self.salary = salary

# %%
emp2 = Employee()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 emp2 = Employee()
#
# TypeError: Employee.__init__() missing 3 required positional arguments: 'name', 'email', and 'salary'

# %%
# Create instances of the Employee class
emp1 = Employee("mohamed", "mohamed@gmail.com", 91208)
emp2 = Employee("sara", "sara@gmail.com", 60000)

# %%
emp1.name
# Out:
# 'mohamed'

# %%
emp1.email
# Out:
# 'mohamed@gmail.com'

# %%
emp2.email
# Out:
# 'sara@gmail.com'

# %%
print(f"Name {emp1.name} email {emp1.email} salary {emp1.salary}")
print(f"Name {emp2.name} email {emp2.email} salary {emp2.salary}")

# %% [markdown]
# ### 5. Operations on Objects (Instances) using methods
# - **An instance method like (`print_employee_info`)** is a function inside a class that can access and modify object attributes.

# %%
class Employee:
    """Represents an Employee with name, email, and salary attributes."""

    def __init__(self, name, email, salary):
        """Initializes an Employee object with given attributes."""
        self.name = name
        self.email = email
        self.salary = salary


    def print_employee_info(self):
        """Instance method to print employee details."""
        print(f'Employee Name: {self.name} | Email: {self.email} | Salary: ${self.salary:,}')

    def calculate_salary(self):
        print(self.salary * .8)

# %%
# Creating Employee objects
emp1 = Employee("ahmed ali", "ahmed@yahoo.com", 6000)
emp2 = Employee("Ali", "ali@yahoo.com", 10000)
emp1.calculate_salary()
emp2.calculate_salary()
# Out:
# 4800.0
# 8000.0

# %%
# Calling the instance method to print details
emp1.print_employee_info()
emp2.print_employee_info()
# Out:
# Employee Name: ahmed ali | Email: ahmed@yahoo.com | Salary: $6,000
# Employee Name: Ali | Email: ali@yahoo.com | Salary: $10,000

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Counting Number of Objects in a Class
#
# - We can track the number of objects created from a class using a **class variable.**
# - **A class variable** belongs to the class itself, not to any specific object.

# %%
class Employee:
    """Represents an Employee and tracks the number of objects created."""
    count = 0  # Class variable Shared among all instances to count instances Created

    def __init__(self, name, email, salary):
        """Initializes an Employee object and increments the count."""
        self.name = name
        self.email = email
        self.salary = salary        # print(self.__class__)
        self.__class__.count += 1   # Increment the count of Employee instances
        self.id = Employee.count

    def print_employee_info(self):
        """Displays the employee's details."""
        print(f'ID: {self.id} | Name: {self.name} | Email: {self.email} | Salary: ${self.salary:,}')

# %%
# Creating Employee objects
emp1 = Employee("Ahmed", "ahmed@example.com", 5000)

# %%
emp2 = Employee("Ali", "ali@example.com", 7000)

# %%
# Calling the instance method
emp1.print_employee_info()
emp2.print_employee_info()
# Out:
# ID: 1 | Name: Ahmed | Email: ahmed@example.com | Salary: $5,000
# ID: 2 | Name: Ali | Email: ali@example.com | Salary: $7,000

# %% [markdown]
# > <span style="background:LemonChiffon">Access **class variable** using className</span>

# %%
emp1.age = 20

# %%
Employee.count
# Out:
# 2

# %%
# Display total number of objects created
print(f"Total Employees Created: {Employee.count}")
# Out:
# Total Employees Created: 2

# %% [markdown]
# > <span style="background:LemonChiffon">Modify **class variable** using className</span>

# %%
Employee.count = 10

# %%
print(f"Total Employees Created: {Employee.count}")
# Out:
# Total Employees Created: 10

# %%
emp3 = Employee("hend", "hend@example.com", 100000)

# %%
print(f"Total Employees Created: {Employee.count}")
# Out:
# Total Employees Created: 11

# %% [markdown]
# ---
# ### 6.1 Displaying Object Properties as a Dictionary
#
# > Every object has a built-in `__dict__` attribute that stores **all instance attributes** and their values as a dictionary.

# %%
emp3 = Employee("hend", "hend@example.com", 100000)
print(emp3)

# %%
print(emp3.__dict__)
# Out:
# {'name': 'hend', 'email': 'hend@example.com', 'salary': 100000, 'id': 12}

# %% [markdown]
# ### 7. Dealing with Class methods and Factory Method

# %%
class Employee:
    """Represents an Employee and tracks the number of instances created."""
    count = 0  # Shared class variable to track total employees

    def __init__(self, name="", email="", salary=0):
        """Initializes an Employee object with default or given values."""
        self.name = name
        self.email = email
        self.salary = salary
        self.__class__.count += 1  # Increment total count
        # Employee.count += 1
        self.id = Employee.count  # Assign unique ID

    def print_employee_info(self):
        """Displays the employee's details."""
        print(f'ID: {self.id} | Name: {self.name} | Email: {self.email} | Salary: ${self.salary:,}')

    @classmethod # Decorator --> changes function behavior to operate on the class level
    def display_employees_count(cls):
        """Displays the total number of employees."""
        print(f"Total number of employees: {cls.count}")

    @classmethod
    def create_emp(cls):
        """Creates a default employee instance."""
        return cls("Default User", "default@gmail.com", 30000)

    def create_employee(self):
        """Creates a new Employee instance with preset values."""
        return self.__class__("Ahmed", "ahmed@gmail.com", 20000)

# %% [markdown]
# > **Class method** call using class name

# %%
emp = Employee("" , "" , 10000)
emp.create_employee()

# %%
Employee.create_emp()

# %%
Employee.display_employees_count()  # Display total employee count

# %%
emp1 = Employee("Ahmed", "ahmed@example.com", 5000)
emp2 = Employee("Ali", "ali@example.com", 7000)

# %%
Employee.count

# %%
Employee.display_employees_count()  # Display total employee count

# %%
emp3 = Employee.create_emp()  # Creates a default employee instance
emp3.print_employee_info()

# %%
Employee.display_employees_count()  # Display total employee count

# %%
# Create an initial Employee object
emp1 = Employee("Test", "Test@example.com", 50000)
# Print the details of the new Employee object
emp2.print_employee_info()

# %%
# Use create_employee() to generate a new Employee instance with preset values

emp1 = emp1.create_employee()
# Print the details of the new Employee object
emp2.print_employee_info()

# %% [markdown]
# ---

# %% [markdown]
# ### 8. Static Method

# %%
class Employee:
    def __init__(self, name, email, salary):
        self.name = name
        self.email = email
        self.salary = salary

    @staticmethod  # Static method doesn't depend on instance or class
    def cal_net_salary(salary):
        """Helper method to calculate net salary"""
        return salary * 0.8

    # def cal_net_salary(self):
    #     """Helper method to calculate net salary"""
    #     return self.salary * 0.8

# %%
# Create an Employee instance
emp = Employee("test", "test@gmail.com", 10000)

# Use static method to calculate net salary
print(Employee.cal_net_salary(20000))  # Can be called directly using the class


print(Employee.cal_net_salary(emp.salary))  # Can also be called using the instance

# %% [markdown]
# Inheritance from the Base Object Class
# In Python, all classes inherit from the base class object. This allows every class to have some common features, such as attributes like __class__ and methods like __str__.

# %% [markdown]
# ### 📝 **Notes**
# > any object in python isinstance of object

# %%
class Employee:
    pass

emp = Employee()
# isinstance(var, datatype)
# Check if p is an instance of Employee or its base class (object)
print(isinstance(emp, Employee))  # True
print(isinstance(emp, object))  # True
print(isinstance(12, object))  # True, because strings also inherit from object
# Out:
# True
# True
# True
